# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/abhishek/Documents/Project_830/Data/control.csv", header=1)
df.head(15)
# Out:
#                                  Start Date  \
# 0   {"ImportId":"startDate","timeZone":"Z"}
# 1                       2026-02-13 02:42:43
# 2                       2026-02-13 04:08:08
# 3                       2026-02-13 15:54:08
# 4                       2026-02-13 15:55:50
# 5                       2026-02-13 16:46:23
# 6                       2026-02-13 17:03:18
# 7                       2026-02-13 17:54:15
# 8                       2026-02-13 17:54:35
# 9                       2026-02-13 17:55:02
# 10                      2026-02-13 17:55:31
#
#                                  End Date          Response Type  \
# 0   {"ImportId":"endDate","timeZone":"Z"}  {"ImportId":"status"}
# 1                     2026-02-13 02:44:21                      1
# 2                     2026-02-13 04:09:12                      1
# 3                     2026-02-13 15:54:32                      1
# 4                     2026-02-13 15:56:09                      1
# ...

# %%
df = pd.read_csv("/Users/abhishek/Documents/Project_830/Data/treatment_clean.csv", header=1)
df.head(15)
# Out:
#   {"ImportId":"startDate","timeZone":"Z"}  \
# 0                     2026-02-13 17:47:19
# 1                     2026-02-13 17:48:15
# 2                     2026-02-13 17:51:37
# 3                     2026-02-13 17:52:08
# 4                     2026-02-13 17:52:31
# 5                     2026-02-13 17:53:02
#
#   {"ImportId":"endDate","timeZone":"Z"}  {"ImportId":"status"}  \
# 0                   2026-02-13 17:48:05                      1
# 1                   2026-02-13 17:48:49                      1
# 2                   2026-02-13 17:52:04                      1
# 3                   2026-02-13 17:52:28                      1
# 4                   2026-02-13 17:53:00                      1
# 5                   2026-02-13 17:53:27                      1
#
#    {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}  \
# 0                       NaN                      100                       46
# ...

# %%
df = pd.read_csv("/Users/abhishek/Documents/Project_830/Data/combined.csv", header=1)
df.head(15)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  {"ImportId":"progress"}  \
# 0          NaN         NaN         NaN         NaN                      100
# 1          NaN         NaN         NaN         NaN                      100
# 2          NaN         NaN         NaN         NaN                      100
# 3          NaN         NaN         NaN         NaN                      100
# 4          NaN         NaN         NaN         NaN                      100
# 5          NaN         NaN         NaN         NaN                      100
# 6          NaN         NaN         NaN         NaN                      100
# 7          NaN         NaN         NaN         NaN                      100
# 8          NaN         NaN         NaN         NaN                      100
# 9          NaN         NaN         NaN         NaN                      100
# 10         NaN         NaN         NaN         NaN  {"ImportId":"progress"}
# ...
